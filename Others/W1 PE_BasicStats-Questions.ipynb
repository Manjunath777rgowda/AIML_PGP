# %% [markdown]
# # 1.Import necessary packages

# %%
import numpy as np
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# drive.mount('/content/drive')

# %% [markdown]
# # 2.Load the file

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Inc_Exp_Data.csv')

# %% [markdown]
# # 3.Analyze the data

# %%
df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
df.describe(include='all')
# Out:
#         Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count         50.000000         50.000000          50.000000        50.000000
# unique              NaN               NaN                NaN              NaN
# top                 NaN               NaN                NaN              NaN
# freq                NaN               NaN                NaN              NaN
# mean       41558.000000      18818.000000           4.060000      3060.000000
# std        26097.908979      12090.216824           1.517382      6241.434948
# min         5000.000000       2000.000000           1.000000         0.000000
# 25%        23550.000000      10000.000000           3.000000         0.000000
# 50%        35000.000000      15500.000000           4.000000         0.000000
# 75%        50375.000000      25000.000000           5.000000      3500.000000
# max       100000.000000      50000.000000           7.000000     35000.000000
#
# ...

# %% [markdown]
# # 4.What is the Mean Expense of a Household?

# %%
mean = df.Mthly_HH_Expense.mean()
mean
# Out:
# 18818.0

# %% [markdown]
# # 5.What is the Median Household Expense?

# %%
q2 = df.Mthly_HH_Expense.median()
q2
# Out:
# 15500.0

# %% [markdown]
# # 6.What is the Monthly Expense for most of the Households?

# %%
df.Mthly_HH_Expense.mode()
# Out:
# 0    25000
# dtype: int64

# %% [markdown]
# # 7.Plot the Histogram to count the Highest qualified member

# %%
plt.figure(figsize=(10,7))
sns.histplot(data=df,x='Highest_Qualified_Member');

# %% [markdown]
# # 8.Calculate IQR(difference between 75% and 25% quartile) for monthly income

# %%
df['Mthly_HH_Income'].quantile(0.75)-df['Mthly_HH_Income'].quantile(0.25)
# Out:
# 26825.0

# %% [markdown]
# # 9.Calculate Standard Deviation for first 4 columns.

# %%
pd.DataFrame(df.iloc[:,:4].std().to_frame()).T
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt
# 0     26097.908979      12090.216824           1.517382      6241.434948

# %% [markdown]
# # 10.Calculate Variance for first 3 columns.

# %%
pd.DataFrame(df.iloc[:,:3].std().to_frame()).T
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members
# 0     26097.908979      12090.216824           1.517382

# %% [markdown]
# # 11.Calculate the count of Highest qualified member.

# %%
df['Highest_Qualified_Member'].value_counts()
# Out:
# Graduate          19
# Under-Graduate    10
# Professional      10
# Post-Graduate      6
# Illiterate         5
# Name: Highest_Qualified_Member, dtype: int64

# %% [markdown]
# # 12.Plot the Histogram to count the No_of_Earning_Members

# %%
sns.countplot(data = df, x='No_of_Earning_Members');

# %% [markdown]
# # 13.Suppose you have option to invest in Stock A or Stock B. The stocks • have different expected returns and standard deviations. The expected return of Stock A is 15% and Stock B is 10%. Standard Deviation of the returns of these stocks is 10% and 5% respectively.
#
# Which is better investment?

# %%
a_return=15
b_return=10
a_std=10
b_std=5

a = (a_return-a_std,a_return+a_std)
b = (b_return-b_std,b_return-b_std)
print("a",a)
print("b",b)
# Out:
# a (5, 25)
# b (5, 5)

# %%
a = [2, 4, 4, 3, 8, 67, 23]
pd.Series([2, 4, 4, 3, 8, 67, 23]).median()
# Out:
# 4.0

# %%
import scipy.stats as stats
from scipy.stats import norm
n=30
mu=14
std=3
norm.interval(0.95,loc=mu,scale = std/np.sqrt(30))
# Out:
# (12.926483513769705, 15.073516486230295)

# %%
n=250
xbar=45000
std=4000
norm.interval(0.95,loc=xbar,scale=std/np.sqrt(n))
# Out:
# (44504.16397415635, 45495.83602584365)

# %%
z = (30-32.2)/3.6
z
# Out:
# -0.6111111111111119
