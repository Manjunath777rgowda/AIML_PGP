# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
from scipy.stats import uniform
from scipy.stats import norm
from scipy.stats import binom
from scipy.stats import poisson
import math as math

# %% [markdown]
# # 1.You flip a fair coin 10 times. What is the probability of getting 8 or more heads?

# %%
k = np.arange(0,11);
binomial = binom.pmf(k=k,n=10,p=0.5)
round(sum(binomial[8:]),3)
# Out:
# 0.055

# %% [markdown]
# # 2. The probability that you will win a certain game is 0.3. You play the game 20 times. What is the mean of this binomial distribution?

# %%
p = 0.3
n=20
m=n*p
print(m)
# Out:
# 6.0

# %% [markdown]
# # 3. An automatic camera records the number of cars running a red light at an intersection (that is, the cars were going through when the red light was against the car). Analysis of the data shows that on average 15% of light changes record a car running a red light. Assume that the data has a binomial distribution. What is theprobability that in 20 light changes there will be exactly three (3) cars running a red light?

# %%
from math import factorial
p=0.15
n=20
x=3
combination = factorial(n)/(factorial(x)*factorial(n-x))
result = combination * p**x * (1-p)**(n-x)
result
# Out:
# 0.24282889614926745

# %% [markdown]
# # 4. There are 15 sets of traffic lights on the journey.The probability that a driver must stop at any one traffic light coming to alliance University is 0.3
#
# a) What is the probability that a student must stop at exactly 2 of the 15 sets oftraffic lights?
#
# b) What is the probability that a student will be stopped at 1 or more of the 15sets of traffic lights?

# %%
p = 0.3
n=15
x=2

combination = factorial(n)/(factorial(x)*factorial(n-x))
result = (combination * (p**x)*(1-p)**(n-x))*100
print('{:.2f}% is the probabilitiy that a student must stop at exactly 2 of the 15 sets of traffic lights'.format(result))

x=0
combination = factorial(n)/(factorial(x)*factorial(n-x))
result =(1- combination * (p**x)*(1-p)**(n-x))*100
print('{:.2f}% is the probability that a student will be stopped at 1 or more of the 15sets of traffic lights'.format(result))
# Out:
# 9.16% is the probabilitiy that a student must stop at exactly 2 of the 15 sets of traffic lights
# 99.53% is the probability that a student will be stopped at 1 or more of the 15sets of traffic lights

# %% [markdown]
# # 5. What is the area under the curve of a probability distribution? Explain.

# %% [markdown]
# # 6. My Bank has a large Credit Card portfolio. Based on empirical data, they have found that 60% of the customers pay their bill on time. If a sample of 10 accounts is selected from the current database, construct the Probability Distribution of accounts paying on time.
# Hint: Make use of Function used in Excel or R

# %%
n=10
p=0.6
k=np.arange(0,10)
binomial = binom.pmf(k=k,n=10,p=0.6)
binomial
# Out:
# array([1.04857600e-04, 1.57286400e-03, 1.06168320e-02, 4.24673280e-02,
#        1.11476736e-01, 2.00658125e-01, 2.50822656e-01, 2.14990848e-01,
#        1.20932352e-01, 4.03107840e-02])

# %% [markdown]
# # 7. If the likelihood of a tagged order form is 0.1, What is the probability that there are three tagged order forms in the sample of four?
# Hint: Use Binomial distribution equation

# %%
n=4
x=3
p=0.1
combination = factorial(n)/(factorial(x)*factorial(n-x))
result = combination * p**x * (1-p)**(n-x)
result
# Out:
# 0.0036000000000000008

# %% [markdown]
# # 8. Determine the following:
#
# a) For n = 4 and p = 0.12, what is P(X = 0)?
#
# b) For n = 6 and p = 0.83, what is P(X = 5)?

# %%
n=4
x=0
p=0.12
combination = factorial(n)/(factorial(x)*factorial(n-x))
result = combination * p**x * (1-p)**(n-x)
print(result)
print(binom.pmf(x,n,p))
# Out:
# 0.59969536
# 0.59969536

# %%
n=6
x=5
p=0.83
combination = factorial(n)/(factorial(x)*factorial(n-x))
result = combination * p**x * (1-p)**(n-x)
print(result)
print(binom.pmf(x,n,p))
# Out:
# 0.40178214558599995
# 0.401782145586

# %% [markdown]
# # 9.Determine the mean and standard deviation of the variable X in each of the following binomial distributions:
#
# a) n = 4 and p = 0.10
#
# b) n = 5 and p = 0.80

# %%
n=4
p=0.10
mu=n*p
std = math.sqrt(mu*(1-p))
print('({:.2f},{:.2f})'.format(mu,std))

n=5
p=0.8
mu=n*p
std = math.sqrt(mu*(1-p))
print('({:.2f},{:.2f})'.format(mu,std))
# Out:
# (0.40,0.60)
# (4.00,0.89)

# %% [markdown]
# # 10. Assume a poisson distribution with lambda = 5.0. What is the probability that
# a) X <= 1?
#
# b) X > 1?

# %%
rate=5.0
n=np.arange(0,20)
pd = poisson.pmf(n,rate)
print('{:.4f}'.format(sum(pd[:2])))
print('{:.4f}'.format(1-sum(pd[:2])))
# Out:
# 0.0404
# 0.9596

# %% [markdown]
# # 11. The number of work related injuries per month in a manufacturing plant is known to follow a Poisson distribution, with a mean of 2.5 work-related injuries a month.
#
# a) What is the probability that in a given month, no work-related injuries occur?
#
# b) That at least one work- related injury occurs?
#
# Hint: Use Poisson distribution equation, find X = 0, Given lambda = 2.5

# %%
rate=2.5
n=np.arange(0,20)
pd = poisson.pmf(n,rate)
print('{:.4f}'.format(pd[0]))
print('{:.4f}'.format(1-pd[0])))
# Out:
# 0.0821
# 0.9179

# %% [markdown]
# # 12. A 5-litre bucket of water is taken from a swamp. The water contains 75 mosquito larvae. A 200mL flask of water is taken form the bucket for further analysis. What is
#
# a) the expected number of larvae in the flask?
#
# b) the probability that the flask contains at least one mosquito lava?

# %%
rate=(75/5000)*200
print(' the expected number of larvae in the flask is ',rate)
# Out:
#  the expected number of larvae in the flask is  3.0

# %%
pd = poisson.pmf(n,rate)
print(' the probability that the flask contains at least one mosquito lava ',round(1-pd[0],2))
# Out:
#  the probability that the flask contains at least one mosquito lava  0.95

# %% [markdown]
# # 13. Why the need of Standardization? Why do we us Z instead of “the Number of Standard Deviations”?

# %% [markdown]
# # 14. A radar unit is used to measure speeds of cars on a Mumbai – Pune Highway. The speeds are normally distributed with a mean of 70 km/hr and a standard deviation of 10 km/hr.
#
# a)What is the probability that a car picked at random is travelling at more than 100 km/hr?
#
# b)What is the probability that the car speed is between 80 Km / hr and 100 Km / hr
#
# Hint: You can make use of Excel

# %%
mu=70
std=10
x=100

# z= (x-mu)/std
result1=1-norm.cdf(x,mu,std)
print('{:.3f} is the probability that a car picked at random is travelling at more than 100 km/hr'.format(result1))

result2 = (norm.cdf(x,mu,std) - norm.cdf(80,mu,std))
print('{:.3f} is the probability that the car speed is between 80 Km / hr and 100 Km / hr'.format(result2))
# Out:
# 0.001 is the probability that a car picked at random is travelling at more than 100 km/hr
# 0.157 is the probability that the car speed is between 80 Km / hr and 100 Km / hr

# %% [markdown]
# # 15. The percentage of orders filled correctly at Wendy's was approximately 86.8%. Suppose that you go to drive-through window at Wendy's and place an order. Two friends of yours independently place orders at the drive-through window at the same Wendy's.
#
# What are the probabilities that
#
# a) all three filled correctly?
#
# b) none of the three filled correctly?
#
# c) atleast two of the three orders will be filled correctly?
#
# d) what is the mean and standard deviation of the orders filled correctly?

# %%
p=0.868
n=3
k=np.arange(0,4)
bd = binom.pmf(k,n,p)
print('The probability of all three filled correctly is {:.2f}'.format(bd[3]))
print('The probability of none of the three filled correctly is {:.2f}'.format(bd[0]))
print('The probability of atleast two of the three orders will be filled correctly {:.2f}'.format(sum(bd[2:])))
print('The mean and stadard deviation of the orders filled correctly is ({:.2f},{:.2f})'.format(n*p,math.sqrt((n*p)*(1-p))))
# Out:
# The probability of all three filled correctly is 0.65
# The probability of none of the three filled correctly is 0.00
# The probability of atleast two of the three orders will be filled correctly 0.95
# The mean and stadard deviation of the orders filled correctly is (2.60,0.59)

# %%
p=0.5
n=30
k=np.arange(0,31)
bd= binom.pmf(k,n,p)
print('My answer',round(sum(bd[20:]),4))
print('Gagan suggested answer',1-binom.cdf(19,n,p))
print('Correct answer is : 0.0505')
# Out:
# My answer 0.0494
# Gagan suggested answer 0.04936857335269451
# Correct answer is : 0.0505
# 15.0
# 5.477225575051661

# %%
mu = 75000
std = 12000
a=80000
b=100000
(norm.cdf(b,mu,std)-norm.cdf(a,mu,std))/(1-norm.cdf(a ,mu,std))
# Out:
# 0.9450145847866034

# %%
mu=5
n=np.arange(0,20)
poisson.pmf(n,mu)[3]
# Out:
# 0.1403738958142805

# %%
mu=70
std=10
norm.cdf(80,mu,std)
# Out:
# 0.8413447460685429

# %%
1/4
# Out:
# 0.25
