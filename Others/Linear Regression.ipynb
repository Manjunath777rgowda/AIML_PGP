# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import scipy.stats as stats

# %%
# Adjusted R-square
n=470
r_sqr = 0.35
k=3
ad_r_squer = 1 - (((n-1)*(1-r_sqr))/(n-(k+1)))
ad_r_squer
# Out:
# 0.3458154506437767

# %%
x= [ 4, 6, 9, 10, 11]
y= [ 2 ,4 ,4, 7, 8]
slope_intercept = np.polyfit(x,y,1)
slope_intercept
# Out:
# array([ 0.76470588, -1.11764706])

# %%
x= [ 4, 5, 8, 10, 11]
y= [50, 48, 45 , 42, 41]
nested_list = [x,y]

# creating DataFrame
df = pd.DataFrame(nested_list)
df.cor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-ab88d9a10884> in <module>
#       5 # creating DataFrame
#       6 df = pd.DataFrame(nested_list)
# ----> 7 df.cor()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'cor'

# %%
import sklearn
import math
actual = [18.3,17.2,23.6,17.9,16.9]
predicted = [18.9,16.7,24.6,19.2,15.5]
mse = sklearn.metrics.mean_squared_error(actual, predicted)
rmse = math.sqrt(mse)
rmse
# Out:
# 1.0256705123966463

# %%
x_simple = np.array([ 4, 5, 8, 10, 11])
y_simple = np.array([50, 48, 45 , 42, 41]
                    )
my_rho = np.corrcoef(x_simple, y_simple)

print(my_rho)
# Out:
# [[ 1.         -0.99638179]
#  [-0.99638179  1.        ]]
